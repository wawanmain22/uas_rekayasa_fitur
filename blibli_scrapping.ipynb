# %%
# Import required libraries
import json
import pandas as pd
from tqdm import tqdm
from google_play_scraper import Sort, reviews, app
from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

# %%
# Setup output directory for local machine
import os

# Create output directory if it doesn't exist
output_dir = "output"
os.makedirs(output_dir, exist_ok=True)

# %%
# Define app packages to scrape
# List of Android app package names for Indonesian e-commerce apps
app_pack = [
    'blibli.mobile.commerce'  # Blibli - Indonesian e-commerce platform
]

# Display as DataFrame for better visualization
import pandas as pd
pd.DataFrame({'App Package': app_pack, 'Description': ['Blibli - Indonesian e-commerce platform']})
# Out:
#               App Package                              Description
# 0  blibli.mobile.commerce  Blibli - Indonesian e-commerce platform

# %%
# Scrape app information
# Get basic app information from Google Play Store
app_info = []

for apps in tqdm(app_pack, desc="Getting app info"):
    # Get app details in Indonesian language for Indonesian market
    info = app(apps, lang='id', country='id')
    
    # Remove comments section to keep only basic app info
    del info['comments']
    app_info.append(info)

# Display app info as DataFrame
app_info_df = pd.DataFrame(app_info)
app_info_df
# Out:
# Getting app info:   0%|          | 0/1 [00:00<?, ?it/s]
# Getting app info: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s]
#     title                                        description  \
# 0  Blibli  Kamu bisa pakai promonya buat belanja online m...
#
#                                      descriptionHTML  \
# 0  Kamu bisa pakai promonya buat belanja online m...
#
#                                              summary     installs  \
# 0  100% Orisinil, Gratis Ongkir, Pengiriman Cepat...  10.000.000+
#
#    minInstalls  realInstalls     score  ratings  reviews  ... contentRating  \
# 0     10000000      46048944  4.739756   662803   175830  ...     Rating 3+
#
#    contentRatingDescription  adSupported containsAds    released  \
# 0                      None        False       False  9 Des 2013
#
#   lastUpdatedOn     updated version                   appId  \
# 0    2 Agu 2025  1754074989  12.5.5  blibli.mobile.commerce
#
#                                                  url
# 0  https://play.google.com/store/apps/details?id=...
#
# [1 rows x 44 columns]

# %%
# Scrape app reviews
# Get reviews for each app across all ratings (1-5 stars) and sort orders
print("Scraping app reviews...")
app_revue = []

for ap in tqdm(app_pack, desc="Scraping reviews"):
    # Loop through each rating score (1-5 stars)
    for score in list(range(1, 6)):
        # Loop through different sort orders
        for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
            # Get more reviews for neutral rating (score=3) as they provide balanced insights
            count = 9000 if score == 3 else 5000
            
            # Scrape reviews with current parameters
            rvs, _ = reviews(
                ap,                    # App package name
                lang='id',             # Indonesian language
                country='id',          # Indonesian market
                sort=sort_order,       # Sort order (most relevant or newest)
                count=count,           # Number of reviews to fetch
                filter_score_with=score # Filter by rating score
            )
            
            # Add metadata to each review
            for r in rvs:
                r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
                r['appId'] = ap
                
            # Add reviews to main list
            app_revue.extend(rvs)

print(f"Successfully scraped {len(app_revue)} reviews")
# Out:
# Scraping app reviews...
# Scraping reviews: 100%|██████████| 1/1 [00:44<00:00, 44.49s/it]
# Successfully scraped 58000 reviews

# %%
# Display sample reviews
# Show first 3 reviews to verify data structure
sample_df = pd.DataFrame(app_revue[0:3])
sample_df
# Out:
#                                reviewId         userName  \
# 0  34c0068e-9464-4eb6-91a6-0b0413f496c3  Pengguna Google
# 1  4040d0cc-0c4a-48c5-be52-971781b97990  Pengguna Google
# 2  6315b567-3118-4458-bb13-7efd75d8306d  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  saya order barang helm, saya tidak ada cancel ...      1             17
# 1  alamat tidak bisa disesuaikan dengan aslinya ,...      1             67
# 2  Saya heran, sudah nonaktifkan notifikasi dari ...      1             21
#
#   reviewCreatedVersion                  at  \
# 0               12.5.5 2025-07-25 18:28:42
# 1               12.4.5 2025-07-05 19:20:58
# 2               12.5.5 2025-07-17 07:38:24
#
#                                         replyContent           repliedAt  \
# 0  Halo kak Frans mohon maaf terkait proses order... 2025-07-30 15:38:44
# 1  Halo kak, mohon maaf atas pengalaman belanja y... 2025-07-05 19:40:27
# 2  Halo kak Ridwan mohon maaf terkait notifikasi ... 2025-07-20 14:36:13
#
#   appVersion      sortOrder                   appId
# 0     12.5.5  most_relevant  blibli.mobile.commerce
# 1     12.4.5  most_relevant  blibli.mobile.commerce
# 2     12.5.5  most_relevant  blibli.mobile.commerce

# %%
# Convert to DataFrame and sort by date
# Create pandas DataFrame from review list
data_review = pd.DataFrame(app_revue)

# Sort reviews by date (newest first)
data_review = data_review.sort_values('at', ascending=False)

data_review
# Out:
#                                    reviewId         userName  \
# 42159  ffca2a84-9212-41f9-b25d-896d57a0bc8b  Pengguna Google
# 43000  ffca2a84-9212-41f9-b25d-896d57a0bc8b  Pengguna Google
# 53000  3cf56805-2a66-46c9-ab92-7bdf1624d72c  Pengguna Google
# 53001  3fbb7d3f-dba6-4fa3-90cb-87c160ad182e  Pengguna Google
# 5000   e77d54c6-f431-44e3-9865-50ad67113895  Pengguna Google
# ...                                     ...              ...
# 27833  538ed255-8837-48df-9e9b-e1a5a53c1a11  Pengguna Google
# 27835  aef97273-7329-4221-aba4-4064e2678789  Pengguna Google
# 14321  f2489bff-f3c2-4e97-b68b-6c2c9fcfac36  Pengguna Google
# 27834  c357a52f-4e00-45d8-9c52-bf61f0dfe6a1  Pengguna Google
# 27836  616cabdc-0803-4967-a9ca-0e1fc6506839  Pengguna Google
#
#                                                userImage  \
# 42159  https://play-lh.googleusercontent.com/EGemoI2N...
# 43000  https://play-lh.googleusercontent.com/EGemoI2N...
# 53000  https://play-lh.googleusercontent.com/EGemoI2N...
# 53001  https://play-lh.googleusercontent.com/EGemoI2N...
# 5000   https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 27833  https://play-lh.googleusercontent.com/EGemoI2N...
# 27835  https://play-lh.googleusercontent.com/EGemoI2N...
# 14321  https://play-lh.googleusercontent.com/EGemoI2N...
# 27834  https://play-lh.googleusercontent.com/EGemoI2N...
# 27836  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 42159  aplikasi nya kurang ini masa paylater saya d t...      4
# 43000  aplikasi nya kurang ini masa paylater saya d t...      4
# 53000                                mantap ini aplikasi      5
# 53001                                             mantab      5
# 5000   mau log in D aplikasi ini susah padah sinyal b...      1
# ...                                                  ...    ...
# 27833                                              Keren      3
# 27835                                           Mantap..      3
# 14321                        Jelek banget susah masuknya      2
# 27834                         Mantap,up 2 date trus ya..      3
# 27836                                             nice ,      3
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 42159              0               12.5.5 2025-08-02 15:21:53
# 43000              0               12.5.5 2025-08-02 15:21:53
# 53000              0               12.5.5 2025-08-02 10:56:00
# 53001              0               12.5.5 2025-08-02 06:56:00
# 5000               0               12.5.5 2025-08-02 04:52:36
# ...              ...                  ...                 ...
# 27833              0                1.4.3 2014-05-16 21:41:32
# 27835              0                1.4.2 2014-05-15 08:33:35
# 14321              0                1.4.2 2014-05-08 01:00:28
# 27834              0                1.4.2 2014-05-02 21:36:16
# 27836              0                1.3.3 2014-03-19 16:46:04
#
#                                             replyContent           repliedAt  \
# 42159                                               None                 NaT
# 43000                                               None                 NaT
# 53000  Halo kak Daamxyz. mantap! Makasih banyak buat ... 2025-08-02 12:50:35
# 53001  Halo kak mantap! Makasih banyak buat review ke... 2025-08-02 08:20:04
# 5000   Halo kak Asep mohon maaf terkait terkait kenda... 2025-08-02 06:24:28
# ...                                                  ...                 ...
# 27833  Thank you blibli friend for good review :) hop... 2020-02-15 08:45:27
# 27835  Thank you blibli friend for good review :) hop... 2020-02-15 08:45:32
# 14321  Sangat disayangkan sekali dengan kondisinya :(... 2020-02-29 16:59:17
# 27834  terima kasih untuk reviewnya yang keren banget... 2020-02-29 17:03:22
# 27836  Thank you blibli friend for good review :) hop... 2020-02-15 08:47:52
#
#       appVersion      sortOrder                   appId
# 42159     12.5.5  most_relevant  blibli.mobile.commerce
# 43000     12.5.5         newest  blibli.mobile.commerce
# 53000     12.5.5         newest  blibli.mobile.commerce
# 53001     12.5.5         newest  blibli.mobile.commerce
# 5000      12.5.5         newest  blibli.mobile.commerce
# ...          ...            ...                     ...
# 27833      1.4.3  most_relevant  blibli.mobile.commerce
# 27835      1.4.2  most_relevant  blibli.mobile.commerce
# 14321      1.4.2  most_relevant  blibli.mobile.commerce
# 27834      1.4.2  most_relevant  blibli.mobile.commerce
# 27836      1.3.3  most_relevant  blibli.mobile.commerce
#
# [58000 rows x 13 columns]

# %%
# Clean and prepare data for export
# Select only relevant columns for analysis
refine_data = data_review[['reviewId', 'userName', 'content', 'score', 'at', 'replyContent', 'repliedAt', 'appId']].copy()

# Fix datetime formatting and remove timezone info for better compatibility
refine_data['at'] = pd.to_datetime(refine_data['at']).dt.tz_localize(None)
refine_data['repliedAt'] = pd.to_datetime(refine_data['repliedAt']).dt.tz_localize(None)

# Rename columns to more descriptive names
refine_data.rename(columns={
    'reviewId': 'review_id', 
    'userName': 'username', 
    'at': 'created_at',
    'replyContent': 'reply_content',
    'repliedAt': 'replied_at', 
    'appId': 'app_id'
}, inplace=True)

# Remove duplicate reviews based on review_id
refine_data.drop_duplicates(subset=['review_id'], inplace=True)

# Reset index after cleaning
refine_data.reset_index(drop=True, inplace=True)

refine_data
# Out:
#                                   review_id         username  \
# 0      ffca2a84-9212-41f9-b25d-896d57a0bc8b  Pengguna Google
# 1      3cf56805-2a66-46c9-ab92-7bdf1624d72c  Pengguna Google
# 2      3fbb7d3f-dba6-4fa3-90cb-87c160ad182e  Pengguna Google
# 3      e77d54c6-f431-44e3-9865-50ad67113895  Pengguna Google
# 4      9be6ab30-0b54-41f5-afab-aef3c68a858d  Pengguna Google
# ...                                     ...              ...
# 40815  538ed255-8837-48df-9e9b-e1a5a53c1a11  Pengguna Google
# 40816  aef97273-7329-4221-aba4-4064e2678789  Pengguna Google
# 40817  f2489bff-f3c2-4e97-b68b-6c2c9fcfac36  Pengguna Google
# 40818  c357a52f-4e00-45d8-9c52-bf61f0dfe6a1  Pengguna Google
# 40819  616cabdc-0803-4967-a9ca-0e1fc6506839  Pengguna Google
#
#                                                  content  score  \
# 0      aplikasi nya kurang ini masa paylater saya d t...      4
# 1                                    mantap ini aplikasi      5
# 2                                                 mantab      5
# 3      mau log in D aplikasi ini susah padah sinyal b...      1
# 4                                                     ok      5
# ...                                                  ...    ...
# 40815                                              Keren      3
# 40816                                           Mantap..      3
# 40817                        Jelek banget susah masuknya      2
# 40818                         Mantap,up 2 date trus ya..      3
# 40819                                             nice ,      3
#
#                created_at                                      reply_content  \
# 0     2025-08-02 15:21:53                                               None
# 1     2025-08-02 10:56:00  Halo kak Daamxyz. mantap! Makasih banyak buat ...
# 2     2025-08-02 06:56:00  Halo kak mantap! Makasih banyak buat review ke...
# 3     2025-08-02 04:52:36  Halo kak Asep mohon maaf terkait terkait kenda...
# 4     2025-08-02 04:36:55  Halo kak Maulana mantap! Makasih banyak buat r...
# ...                   ...                                                ...
# 40815 2014-05-16 21:41:32  Thank you blibli friend for good review :) hop...
# 40816 2014-05-15 08:33:35  Thank you blibli friend for good review :) hop...
# 40817 2014-05-08 01:00:28  Sangat disayangkan sekali dengan kondisinya :(...
# 40818 2014-05-02 21:36:16  terima kasih untuk reviewnya yang keren banget...
# 40819 2014-03-19 16:46:04  Thank you blibli friend for good review :) hop...
#
#                replied_at                  app_id
# 0                     NaT  blibli.mobile.commerce
# 1     2025-08-02 12:50:35  blibli.mobile.commerce
# 2     2025-08-02 08:20:04  blibli.mobile.commerce
# 3     2025-08-02 06:24:28  blibli.mobile.commerce
# 4     2025-08-02 06:21:50  blibli.mobile.commerce
# ...                   ...                     ...
# 40815 2020-02-15 08:45:27  blibli.mobile.commerce
# 40816 2020-02-15 08:45:32  blibli.mobile.commerce
# 40817 2020-02-29 16:59:17  blibli.mobile.commerce
# 40818 2020-02-29 17:03:22  blibli.mobile.commerce
# 40819 2020-02-15 08:47:52  blibli.mobile.commerce
#
# [40820 rows x 8 columns]

# %%
# Save data to CSV file and display summary statistics
# Export cleaned data to local file
output_file = os.path.join(output_dir, "blibli_app_review.csv")
refine_data.to_csv(output_file, index=False, header=True)

print(f"✅ Data exported successfully to: {output_file}")
print(f"📊 Total records saved: {len(refine_data)}")

# Create summary statistics DataFrame
summary_stats = {
    'Metric': ['Total Reviews', 'Date Range (From)', 'Date Range (To)', 'Average Rating'],
    'Value': [
        len(refine_data),
        refine_data['created_at'].min(),
        refine_data['created_at'].max(),
        f"{refine_data['score'].mean():.2f}"
    ]
}

summary_df = pd.DataFrame(summary_stats)

# Rating distribution DataFrame
rating_dist = refine_data['score'].value_counts().sort_index().reset_index()
rating_dist.columns = ['Rating (Stars)', 'Count']
rating_dist['Percentage'] = (rating_dist['Count'] / len(refine_data) * 100).round(1)

print("\n📈 Summary Statistics:")
display(summary_df)

print("\n⭐ Rating Distribution:")
display(rating_dist)
# Out:
# ✅ Data exported successfully to: output/blibli_app_review.csv
# 📊 Total records saved: 40820
#
# 📈 Summary Statistics:
#               Metric                Value
# 0      Total Reviews                40820
# 1  Date Range (From)  2014-03-19 16:46:04
# 2    Date Range (To)  2025-08-02 15:21:53
# 3     Average Rating                 3.10
# ⭐ Rating Distribution:
#    Rating (Stars)  Count  Percentage
# 0               1   7951        19.5
# 1               2   5562        13.6
# 2               3  11347        27.8
# 3               4   6467        15.8
# 4               5   9493        23.3
